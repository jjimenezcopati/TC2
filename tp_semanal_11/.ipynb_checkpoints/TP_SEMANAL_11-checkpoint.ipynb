# %% [markdown]
# # TP SEMANAL N°11
#
# ### Juan Ignacio Jimenez Copati

# %% [markdown]
# ## *CONSIGNA*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## *Desarrollo en papel*

# %%
from IPython.display import IFrame
IFrame("./ts11.pdf", width=960, height=1000)
# Out:
#         <iframe
#             width="960"
#             height="1000"
#             src="./ts11.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
