# %% [markdown]
# # TP SEMANAL N°5
# ### Juan Ignacio Jimenez Copati

# %% [markdown]
# ## *CONSIGNA*

# %% [markdown]
# ![consigna_1.png](attachment:consigna_1.png)

# %% [markdown]
# ![consigna_2.png](attachment:consigna_2.png)

# %% [markdown]
# ![consigna_3.png](attachment:consigna_3.png)

# %% [markdown]
# ## *Recursos usados*

# %% [markdown]
# #### *Fórmula notch pasa bajos*

# %% [markdown]
# ![notch_pb.png](attachment:notch_pb.png)

# %% [markdown]
# ## *Circuitos comparables*

# %% [markdown]
# ![circuito.png](attachment:circuito.png)

# %% [markdown]
# Como se puede ver, otra implementación es con el circuito Ackerberg-Mossberg en complemento con una etapa pasa bajos. El análisis es el siguiente:

# %% [markdown]
# #### *Respuesta en frecuencia*

# %% [markdown]
# ![salida_vs_salidaack.png](attachment:salida_vs_salidaack.png)

# %% [markdown]
# En estas imagenes vemos una comparativa de la respuesta en frecuencia de la parte Ackerberg-Mossberg (en verde)vs la del sistema total (en rosa).
#
# En cuanto al módulo, se puede ver que la clara diferencia es el constante decrecimiento para frecuencias cada vez más elevadas. Esto se debe a la etapa pasa bajos que se agrtegó al final. Sin esta etapa, lo que se obtiene es un filtro notch pasa bajos que atenúa 20dB en frecuencias elevadas.
#
# La fase tiene una diferencia tambien notable, ya que al agregar un filtro pasa bajos, este hace un aporte de polos de un recorrido total de π/2.

# %% [markdown]
# ![cursor.png](attachment:cursor.png)

# %% [markdown]
# Además podemos ver que la frecuencia de la aguja del notch es en 477mHz aprox, lo que se traduce en 3 rad/seg en el eje ω
