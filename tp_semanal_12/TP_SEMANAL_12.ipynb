# %% [markdown]
# # TP SEMANAL N°12
#
# ### Juan Ignacio Jimenez Copati

# %% [markdown]
# ## *CONSIGNA*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## *Desarrollo en papel*

# %%
from IPython.display import IFrame
IFrame("./ts12.pdf", width=960, height=1000)
# Out:
#         <iframe
#             width="960"
#             height="1000"
#             src="./ts12.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
