# %% [markdown]
# # TP SEMANAL N°2
#
# ### Juan Ignacio Jimenez

# %% [markdown]
# ## **Cálculos**

# %%
from IPython.display import IFrame
IFrame("./Tp2.pdf", width=960, height=1000)
# Out:
#         <iframe
#             width="960"
#             height="1000"
#             src="./Tp2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Análisis de sensibilidad

# %%
from IPython.display import IFrame
IFrame("./sensibilidad.pdf", width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="./sensibilidad.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Simulación numérica

# %% [markdown]
# ### Circuito normalizado LP

# %%
from scipy.signal import TransferFunction     #de el scipy solo exporto la funcion transferfunction
from scipy import signal as sig  
import matplotlib.pyplot as plt               #le doy un nombre (plt) al matplotlib para usarlo más comodamente
import numpy as np                            #le doy un nombre (np) al numpy para usarlo más comodamente
import math as m

##### Librería de TC2
from pytc2.general import print_latex, print_subtitle
import pytc2.sistemas_lineales as tc2 #libreria de la catedra.

#Para graficos

import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
mpl.rcParams.update({'font.size':fig_font_size})

#%%
r1=0.1
r2=3
r3=1
c=1

K=r3/r1
w0=1/(r3*c)
Q=r2/r3

num = [K*w0**2]
den=[1,w0/Q,w0**2]
H1 = sig.TransferFunction(num,den)
tc2.pretty_print_lti(num,den)
tc2.analyze_sys(H1,"LP")
# Out:
# $\displaystyle \frac{ 10 }{s^2 + s \,\, 0.3333 +   1 }$

# %% [markdown]
# Se puede ver que con esta expresión de transferencia se cumple con los parámetros solicitados.

# %% [markdown]
# ### Circuito normalizado BP

# %%
r1=0.1
r2=3
r3=1
c=1

K=r2/r1
w0=1/(r3*c)
Q=r2/r3

num = [K*w0/Q, 0]
den=[1,w0/Q,w0**2]
H1 = sig.TransferFunction(num,den)
tc2.pretty_print_lti(num,den)
tc2.analyze_sys(H1,"LP")
# Out:
# $\displaystyle \frac{s \,\,  10 }{s^2 + s \,\, 0.3333 +   1 }$

# %% [markdown]
# ![acercamiento2.png](attachment:acercamiento2.png)

# %% [markdown]
# ### Circuito normalizado butter

# %%
num = [1]
den=[1,1.41,1]
H1 = sig.TransferFunction(num,den)
tc2.pretty_print_lti(num,den)
tc2.analyze_sys(H1,"BUTTER")
# Out:
# $\displaystyle \frac{  1 }{s^2 + s \,\, 1.41 +   1 }$

# %% [markdown]
# ![acercamiento-2.png](attachment:acercamiento-2.png)

# %% [markdown]
# Se puede ver que para lograr el butterworth la Q debe de ser 0.707, por lo que la expreción hallada es la correcta: los -3dB están presentes en ωo.

# %% [markdown]
# ## Gráfico LT

# %% [markdown]
# #### NORMALIZADO ωo=1 y Q=3

# %% [markdown]
# ![primer_circ.png](attachment:primer_circ.png)

# %% [markdown]
# ![bode_full_1.png](attachment:bode_full_1.png)

# %% [markdown]
# ![bode_zoom_1.png](attachment:bode_zoom_1.png)

# %% [markdown]
# ![cursor_1.png](attachment:cursor_1.png)

# %% [markdown]
# En este apartado se simuló el circuito normalizado para los parámetros pedidos. Se puede ver que la fase recorre los 180° previstos. Además se puede apreciar el pequeño salto que hace antes de empezar a atenuar, característicos de los Q grandes, como es el caso. Se ve que alcanza el valor máximo un poco antes que el ωo y que la ωo se ve representada en su frecuencia en Hz: 159mHz. Por último, se puede apreciar la ganancia de 20dB pedida.

# %% [markdown]
# #### Salida pasa banda

# %% [markdown]
# Al salir por la salida pasa banda analizada en papel se obtiene el siguiente gráfico si se mantiene el valor de los componentes:

# %% [markdown]
# ![bode_pb.png](attachment:bode_pb.png)

# %% [markdown]
# ![cursor_pb.png](attachment:cursor_pb.png)

# %% [markdown]
# Como se ve, es un filtro pasa banda con ωo como frecuencia central de paso. Tanto ωo como Q conservaron sus valores, pues el denominador depende de la naturaleza del circuito y no de su salida. Sin embargo, "K" da 30, que se traduce en una ganancia de 29,5dB. Esto último se puede apreciar en los valores del cursor.

# %% [markdown]
# #### BUTTER

# %% [markdown]
# ![butter.png](attachment:butter.png)

# %% [markdown]
# ![bode_butter.png](attachment:bode_butter.png)

# %% [markdown]
# ![cursor.png](attachment:cursor.png)

# %% [markdown]
# El circuito calculado en papel se confirmó: a los 159Hz (correspondiente a ωo=1) se tienen los -3dB, no se tiene ganancia y la fase va de 180° a 0°.

# %% [markdown]
# ### Conclusiones

# %% [markdown]
# Como conclusión se vio que esta topología tiene una salida pasa bajos además de una pasa banda. Se ve que al variar ωo, todavía puedo variar el Q y la ganancia del circuito con otros componentes independientes entre sí y sin afectar a los otros parámetros. Se puede ver a la vez que la sensibilidad entre parámetros es de relacion uno a uno (o inverso). Es decir, que si varío un parámetro un 1%, el otro variará 1% si la sensibilidad es 1 y -1% si la sensibilidad es -1.

# %% [markdown]
# ## Cambios de reentrega

# %% [markdown]
# - Se hicieron los puntos bonus que faltaban
# - Se organizó mejor la información en el pdf
# - Todos los gráficos de LT se hicieron denuevo y con más detalle. Además se simularon circuitos que antes no.
# - Se pasó de matlab a python
