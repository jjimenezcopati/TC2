# %% [markdown]
# # TP SEMANAL N°9
#
# ### Juan Ignacio Jimenez Copati

# %% [markdown]
# ## *CONSIGNA*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## *Desarrollo en papel*

# %%
from IPython.display import IFrame
IFrame("./ts9.pdf", width=960, height=1000)
# Out:
#         <iframe
#             width="960"
#             height="1000"
#             src="./ts9.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## *Análisis circuital parte 1*

# %% [markdown]
# ### *Punto 1*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Se puede observar que al sacar las Zin de las tres configuraciones, estas coinciden en todo punto del eje de frecuencia. Por ende tenemos sus respectivos polos y ceros en los mismos lugares, validando así los tres métodos de síntesis de función.

# %% [markdown]
# ### *Punto 2*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Puede apreciarse la Yin(w) con sus polos en ω= $\sqrt{ 2 }$ y ω= $\sqrt{ 5 }$ y sus ceros en ω=0 , ω= $\sqrt{ \frac{7}{3} }$ y ω= $ \infty$. Los errores en 0 e $\infty$ probablemente se deban al grado de aproximación de los valores de los componentes a las fracciones.
